# %%
import os
import sys

sys.path.append(os.path.abspath(".."))

import pandas as pd
from src.config import DATA_PATH

df = pd.read_json("../" + DATA_PATH, lines=True)

df.head()
# Out:
#    rating                                        title  \
# 0       3            Smells like gasoline! Going back!
# 1       1      Didn’t work at all lenses loose/broken.
# 2       5                                   Excellent!
# 3       5                       Great laptop backpack!
# 4       5  Best Headphones in the Fifties price range!
#
#                                                 text  \
# 0  First & most offensive: they reek of gasoline ...
# 1  These didn’t work. Idk if they were damaged in...
# 2  I love these. They even come with a carry case...
# 3  I was searching for a sturdy backpack for scho...
# 4  I've bought these headphones three times becau...
#
#                                               images        asin parent_asin  \
# 0  [{'small_image_url': 'https://m.media-amazon.c...  B083NRGZMM  B083NRGZMM
# 1                                                 []  B07N69T6TM  B07N69T6TM
# ...

# %%
df.shape
# Out:
# (50000, 10)

# %%
df.columns
# Out:
# Index(['rating', 'title', 'text', 'images', 'asin', 'parent_asin', 'user_id',
#        'timestamp', 'helpful_vote', 'verified_purchase'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   rating             50000 non-null  int64
#  1   title              50000 non-null  str
#  2   text               50000 non-null  str
#  3   images             50000 non-null  object
#  4   asin               50000 non-null  str
#  5   parent_asin        50000 non-null  str
#  6   user_id            50000 non-null  str
#  7   timestamp          50000 non-null  datetime64[ms]
#  8   helpful_vote       50000 non-null  int64
#  9   verified_purchase  50000 non-null  bool
# dtypes: bool(1), datetime64[ms](1), int64(2), object(1), str(5)
# memory usage: 24.6+ MB

# %%
df.isna().sum()
# Out:
# rating               0
# title                0
# text                 0
# images               0
# asin                 0
# parent_asin          0
# user_id              0
# timestamp            0
# helpful_vote         0
# verified_purchase    0
# dtype: int64

# %%
df["rating"].value_counts().sort_index()
# Out:
# rating
# 1     4144
# 2     2117
# 3     3412
# 4     7383
# 5    32944
# Name: count, dtype: int64

# %%
df[["rating", "title", "text"]].sample(5, random_state=42)
# Out:
#        rating                          title  \
# 33553       5     Functional and easy to use
# 9427        5                  Great Product
# 199         4      A good case for the price
# 12447       5  Webcam 2K HD Streaming Camera
# 39489       5                          Great
#
#                                                     text
# 33553  It clamps onto the desk and is easy to use.  I...
# 9427                                       Great Product
# 199    A good case for the price. I was nervous that ...
# 12447                            Small, but does the job
# 39489                                            Awesome
